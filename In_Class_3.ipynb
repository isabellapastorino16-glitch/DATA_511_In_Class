# %% [markdown]
# # Exercise 1 (3 points)
#
# What is the primary purpose of introducing probability in prescriptive analytics?
#
# - (a) To determine deterministic outcomes
# - (b) To calculate mean and median values
# - (c) To deal with uncertainty in decision-making
# - (d) To evaluate descriptive statistics
# - (e) None of the above

# %% [markdown]
# c. dealing with uncertainty in decision making

# %% [markdown]
# # Exercise 2 (4 points)
#
# Explain the difference between a subjective-based and frequency-based probability. Provide a real-world example of each.

# %% [markdown]
# - **Frequency-based** probability relies on repeatable experiments under the same conditions. (Ex. tossing a fair coin)
# - **Subjective-based** probability relies on personal belief or prior experience. (Ex. estimating a  25% chance that NVIDIA stock will grow 5% tomorrow)

# %% [markdown]
# # Exercise 3 (3 points)
#
# What is the meaning of a stochastic process?
#
# - (a) A process with predetermined outcomes
# - (b) A process that is entirely random
# - (c) A process that follows a probability distribution
# - (d) A deterministic simulation model
# - (e) None of the above

# %% [markdown]
# c. a process that follows a probability distribution

# %% [markdown]
# # Exercise 4 (4 points)
#
# What is the probability of drawing a King from a standard deck of 52 cards?

# %% [markdown]
# 4/52 = 1/13

# %% [markdown]
# # Exercise 5 (6 points)
#
# A survey shows that 51.3% of those who like a new product are male. If 65% of respondents like the product, what is the probability that a randomly selected male likes the product (using Bayes’ Theorem)? Among those who don't like it, 47.6% are male.

# %% [markdown]
# - P(likes) = .65
# - P(dislikes) = .35
# - P(male|likes) = .513
# - P(male|dislikes) = .476
#
# (info below  was changed with additional info)
# - P(male|dislikes) = P(male and dislikes) / P(dislikes) = P(male|like) * P(like) / P(dislikes)
#                                                         = .513         * .65     / .35
#                                                         =
#
# We want to find P(likes|male).
#
# P(male) = P(male and likes) + P(male and dislikes)
#         = P(male|likes) * P(likes) + P(male|dislikes) * P(dislikes)
#         =.513 * .65 + .476 * .35
#         =.5
#
#
# P(likes | male) = P(likes and male) / P(male)
#                 = P(male | likes) * P(likes) / P(male)
#                 =.513             * .65      / .5
#                 =.667
